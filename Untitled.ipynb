# %%
import pickle

# %%
with open("sample_network/fairfax", "rb") as f:
    network = pickle.load(f)

# %%
network
# Out:
# {(-77.1021292552498,
#   38.7240429915456): {'name': "{'WOODLEY DR', 'MOUNT ZEPHYR DR'}", 'road_ids': {2,
#    35891,
#    94224}, 'road_names': {'MOUNT ZEPHYR DR',
#    'WOODLEY DR'}, 'roads': [{'am_inject_rate': 0.64,
#     'end': (-77.102399745091, 38.724194510285),
#     'lanes': 1,
#     'length': 1,
#     'name': 'WOODLEY DR',
#     'pm_exit_rate': 0.7,
#     'yellow_clearance': 3}, {'am_inject_rate': 0.64,
#     'end': (-77.1025766899926, 38.7226656393228),
#     'lanes': 1,
#     'length': 5,
#     'name': 'MOUNT ZEPHYR DR',
#     'pm_exit_rate': 0.7,
#     'yellow_clearance': 3}, {'am_inject_rate': 0.64,
#     'end': (-77.0986215803905, 38.7234312679751),
#     'lanes': 1,
#     'length': 14,
#     'name': 'WOODLEY DR',
#     'pm_exit_rate': 0.7,
#     'yellow_clearance': 3}]},
#  (-77.1025766899926,
#   38.7226656393228): {'name': "{'LAUREL RD', 'MOUNT ZEPHYR DR'}", 'road_ids': {2,
#    51790,
#    68042}, 'road_names': {'LAUREL RD',
# ...

# %%
networknetwork.keys[]
